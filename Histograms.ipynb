# %% [markdown]
# Histogram of a grayscale image

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)
hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.xlim([0, 256])
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_22468\2106350825.py:5: SyntaxWarning: invalid escape sequence '\e'
#   img = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)

# %% [markdown]
# Histogram of a color image

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('media\emma.jfif', cv.IMREAD_COLOR)
color = ('b', 'g', 'r')
for i, c in  enumerate(color):
    hist = cv.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color=c)
    plt.xlim([0, 256])
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_22468\1457949990.py:5: SyntaxWarning: invalid escape sequence '\e'
#   img = cv.imread('media\emma.jfif', cv.IMREAD_COLOR)

# %% [markdown]
# Histogram Equalization

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread('media/flowers.jfif', cv.IMREAD_GRAYSCALE)

hist,bins = np.histogram(img.ravel(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.ravel(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

equ = cv.equalizeHist(img)

hist,bins = np.histogram(equ.ravel(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

res = np.hstack((img, equ)) #stacking images side-by-side
plt.axis('off')
plt.imshow(img, cmap='gray')
plt.imshow(res, cmap='gray')
plt.show()
# Out:
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_22468\3147226506.py:11: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img.ravel(),256,[0,256], color = 'r')
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_22468\3147226506.py:22: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equ.flatten(),256,[0,256], color = 'r')

# %% [markdown]
# Gamma Correction

# %%
# %matplotlib inline
import cv2 as cv
import numpy as np

fig, ax = plt.subplots()
gamma = [0.2, 0.5, 1, 2, 5]

for g in gamma:
    table = np.array([(i / 255.0)**(g)*255.0 for i in np.arange(0, 256)]).astype("uint8")
    ax.plot(table, label=r'$\gamma={g}$'.format(g=g))
ax.legend(loc='best')
ax.set_xlim([0, 255])
ax.set_ylim([0, 255])
ax.set_aspect('equal')
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $f(\mathbf{x})^\gamma$')
ax.savefig('transform.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 17
#      15 ax.set_xlabel(r'Input, $f(\mathbf{x})$')
#      16 ax.set_ylabel(r'Output, $f(\mathbf{x})^\gamma$')
# ---> 17 ax.savefig('transform.png')
#      18 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'savefig'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and a set of subplots (in this case, one subplot)
fig, ax = plt.subplots()

# Plot data on the Axes object
ax.plot(x, y, label='Sine Wave')

# Set labels and a title using the Axes object methods
ax.set_xlabel('X Value')
ax.set_ylabel('Y Value')
ax.set_title('A Single Plot')
ax.legend()

# Optional: Adjust layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()
