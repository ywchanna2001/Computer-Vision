# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

transform = np.arange(0,256, dtype="uint8")
fig, ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[F(mathbf{x})$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)
print(img_orig.shape)
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', img_orig)
cv.waitKey(0)
imge_transformed = cv.LUT(img_orig, transform)
cv.imshow('Image_Transformed', imge_transformed)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\e'
# <>:16: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_9480\1799575237.py:16: SyntaxWarning: invalid escape sequence '\e'
#   img_orig = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)
# (225, 225)

# %% [markdown]
# Negative Transform

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

transform = np.arange(255,-1,-1).astype("uint8")
print(transform.shape)
fig, ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[F(mathbf{x})$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', img_orig)
cv.waitKey(0)
imge_transformed = cv.LUT(img_orig, transform)
cv.imshow('Image_Transformed', imge_transformed)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (256,)
# <>:17: SyntaxWarning: invalid escape sequence '\e'
# <>:17: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_9480\2936954231.py:17: SyntaxWarning: invalid escape sequence '\e'
#   img_orig = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)

# %% [markdown]
# Intensive Windowing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

c = np.array([(100, 50), (150, 200)]) #coordinates

t1 = np.linspace(0, c[0,1], c[0,0] + 1 - 0).astype(np.uint8)
print(len(t1))
t2 = np.linspace(c[0,1]+1, c[1,1], c[1,0] - c[0,0]).astype(np.uint8)
print(len(t2))
t3 = np.linspace(c[1,1]+1, 255, 255 - c[1,0]).astype(np.uint8)
print(len(t3))

transform = np.concatenate((t1, t2), axis=0).astype('uint8')
transform = np.concatenate((transform, t3), axis=0).astype('uint8')
print(len(transform))


fig, ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[F(mathbf{x})$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()


img_orig = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', img_orig)
cv.waitKey(0)
imge_transformed = cv.LUT(img_orig, transform)
cv.imshow('Image_Transformed', imge_transformed)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 101
# 50
# 105
# 256
# <>:30: SyntaxWarning: invalid escape sequence '\e'
# <>:30: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_9480\1127908469.py:30: SyntaxWarning: invalid escape sequence '\e'
#   img_orig = cv.imread('media\emma.jfif', cv.IMREAD_GRAYSCALE)
