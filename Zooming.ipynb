# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
im = cv.imread('media\girl2.jfif', cv.IMREAD_REDUCED_GRAYSCALE_2)

scale = 0.5
rows = int(im.shape[0] * scale)
cols = int(im.shape[1] * scale)

zoomed = np.zeros((rows, cols), dtype=im.dtype)
for i in range(rows):
    for j in range(cols):
        zoomed[i, j] = im[int(i / scale), int(j / scale)]

cv.namedWindow('Original', cv.WINDOW_AUTOSIZE)
cv.imshow('Original', im)
cv.waitKey(0)

cv.namedWindow('Zoomed', cv.WINDOW_AUTOSIZE)
cv.imshow('Zoomed', zoomed)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\g'
# <>:4: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\ywcha\AppData\Local\Temp\ipykernel_22572\3939901390.py:4: SyntaxWarning: invalid escape sequence '\g'
#   im = cv.imread('media\girl2.jfif', cv.IMREAD_REDUCED_GRAYSCALE_2)
